# %% [markdown]
# This notebook demonstrates how to create an offset dictionary from IV sweep data.
#
# It was created in May 2023 by Roger Romani, some functions may have changed since then. Feel free to reach out with questions.

# %%
import time as tm
import pickle
from glob import glob
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.fftpack import fft, ifft, fftfreq
mpl.rcParams['figure.figsize'] = [10, 6.5]

from pytesdaq.io.hdf5 import H5Reader
from pytesdaq.processing import process_ivsweep, IVanalysis
from pytesdaq.processing import _iv_didv_tools_plotting as plot


rsh = 5e-3
fs = 1.25e6

# %%
IV_dIdV_sweep_folder = '/sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536'
chans = ['Melange025pcLeft']
channel_num = 0

# %%
# create an object of the H5Reader class 
h5read = H5Reader() 

# get the start time so we know the total time 
start_time = tm.time()

# get the dataframe for the processed raw data
df = []
df = process_ivsweep(
    ivfilepath=IV_dIdV_sweep_folder,
    chans=chans,
    lgcverbose=True, # Switch to True to know which file its on
    lgcsave=False,
)
# get the end time 
end_time = tm.time()

print(f'IV sweep took {(end_time - start_time)/60: .3f} min to process')

#need to flip the QET bias for all the Pyle lab data
df.qetbias*= -1 

#convert the dataframe into a IV object that we can work with
IVobj = IVanalysis(
    df, 
    rshunt = 5e-3,
    nnorm=5, # number of points in normal region
    nsc=5, # number of points in superconducting region
    lgcremove_badseries = False
)

IVobj.rshunt_err = 0.1e-3
# Out:
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T122637_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T122833_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T123028_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T123223_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T123418_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T123613_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T123809_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T124003_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T124159_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T124354_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T124549_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T124745_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T124939_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T125133_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T125328_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T125523_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T125719_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T125913_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T130109_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T130305_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T130500_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T130656_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T130850_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T131045_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T131241_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T131436_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T131632_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T131826_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/didv_I2_D20230317_T132021_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# dIdV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T122612_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T122809_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T123003_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T123159_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T123354_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T123548_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T123745_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T123939_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T124134_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T124330_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T124524_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T124720_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T124915_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T125109_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T125304_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T125458_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T125654_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T125849_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T130044_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T130241_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T130435_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T130632_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T130826_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T131020_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T131217_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T131411_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T131607_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T131802_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
#
# ============================
# Processing dumps in: /sdata1/runs/run26/raw/iv_didv_I2_D20230317_T122536/iv_I2_D20230317_T131956_F0001.hdf5
# ============================
#
# Processing channel Melange025pcLeft (ndarray index = 0)
# ----
# IV processing
# ----
# IV sweep took  2.091 min to process

# %%
#make a few plots to ensure all is well
IVobj.analyze_sweep(lgcplot = True)

# %%
#read in 2 events to get the metadata
didvfilepath = sorted(glob(IV_dIdV_sweep_folder + '/didv_*'))[0]
traces_temp, metadata = h5read.read_many_events(filepath = didvfilepath,
    nevents=2,
    output_format=2,
    detector_chans=chans,
    include_metadata=True,
    adctoamp = True
)

#generate the offset dictionary
offset_dict = IVobj.get_offsets_dict(metadata, chans[channel_num])

print(offset_dict)
# Out:
# {'i0_off': -1.0010473687333174e-08, 'i0_off_err': 5.351860706422348e-11, 'ibias_off': -1.063455154027833e-07, 'ibias_off_err': 1.793729166495244e-10, 'i0_changable_offset': -1.9340659e-07, 'rp': 0.008743759319122597, 'IVobj': <pytesdaq.processing._iv_didv_tools.IVanalysis object at 0x7f6d3b4829e8>}

# %%
#save the offset dictionary
rq_files_path = '/sdata1/runs/run26/RQFiles/'
save_dict_name = 'offsets_' + str(chans[channel_num]) + "_"
print("Save as: " + save_dict_name)

with open(rq_files_path + save_dict_name, 'wb') as handle:
    pickle.dump(offset_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Save as: offsets_Melange025pcLeft_
