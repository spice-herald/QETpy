# %% [markdown]
# # Noise Analysis Test

# %% [markdown]
# ### Imports

# %%
from noise import noise #import the noise class
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load test data

# %%
traces = np.load('traces.npy')

# %% [markdown]
# ### Create noise object

# %%
#savePath = 'example_Figs/' #used for test, user should define new path for test so they don't save over these figs
savePath = '' #user needs to define new path

sampleRate = 625e3 #define sample rate
channels = [ 'PCS1' , 'PES1' , 'PFS1' , 'PAS2' , 'PBS2' , 'PES2' , 'PDS2' ] #define the channel names
g124_noise = noise(traces, sampleRate, channels) #initialize a noise object
g124_noise.set_name('G124 SLAC Run 37 Pulse Tube On') #use the set_name method to name the object

# %% [markdown]
# ####  Lets check that we can't create and instance of noise if the number of channels doesn't match the number of channel names

# %%
chan = ['a', 'b']
fake_noise = noise(traces, sampleRate, chan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-be69412cf262> in <module>()
#       1 chan = ['a', 'b']
# ----> 2 fake_noise = noise(traces, sampleRate, chan)
#
# /nerohome/u1/cwfink/Analysis/python_scripts/python3/Fink_ay250_homework/final_project/noise_analysis/noise.py in __init__(self, traces, sampleRate, channNames, traceGain, name, time, PSD, real_PSD, imag_PSD, corrCoeff, unCorrNoise, corrNoise, real_CSD, imag_CSD, real_CSD_std, imag_CSD_std, CSD, freqs_CSD, sigR, sigC, reA, imA, freqs_fit, results)
#      30
#      31         if len(channNames) != traces.shape[1]:
# ---> 32             raise ValueError("the number of channel names must mach the number of channes in traces!")
#      33
#      34         self.traces = traces
#
# ValueError: the number of channel names must mach the number of channes in traces!

# %% [markdown]
# #### Good, it won't let us create the object!

# %% [markdown]
# ### Calculate the PSD and corrCoeff

# %%
g124_noise.calculate_PSD()
g124_noise.calculate_corrCoeff()

# %% [markdown]
# ### Test plotting of PSD and corrCoeff

# %%
g124_noise.plot_PSD(lgc_overlay=True, lgcSave=True, savePath=savePath)

# %%
g124_noise.plot_PSD(lgc_overlay=False, lgcSave=True, savePath=savePath)

# %%
g124_noise.plot_corrCoeff(lgcSave=True, savePath=savePath)

# %% [markdown]
# ### Test error checking on plots. Try to plot something before we calculate it

# %%
g124_noise.plot_CSD(whichCSD=['66','26'])

# %% [markdown]
# ## Calculate the cross channel power spectral density (CSD)

# %%
g124_noise.calculate_CSD()

# %% [markdown]
# ## Plot a few CSDs

# %%
g124_noise.plot_CSD(whichCSD=['66','26'],lgcSave=True, savePath=savePath)

# %% [markdown]
# ### Try to plot a CSD for a non existant channel

# %%
g124_noise.plot_CSD(whichCSD=['68'])
# Out:
# index out of range

# %% [markdown]
# ### Try to save a figure with a bad path

# %%
g124_noise.plot_CSD(whichCSD=['11'],lgcSave=True, savePath = 'yay/python/is/great')
# Out:
# Invalid save path. Figure not saved

# %% [markdown]
# ## Let's test the de-correlation fitting

# %% [markdown]
#    #### NOTE: this will take a few hours to complete if using the full CSD. Suggest using a subset of the frequencies to check functionality. ie calculate_deCorrelated_noise(freq_range = [0,200])

# %%
g124_noise.calculate_deCorrelated_noise()
# Out:
# calculating CSD
# calculating correlation coefficients
#
#  Fitting frequency bin  0  out of  21875
#
#  ======  0.0 percent Done ================
# /galbadata/analysis/packages/anaconda3/lib/python3.6/site-packages/scipy/optimize/_lsq/least_squares.py:111: UserWarning: `ftol` is too low, setting to machine epsilon 2.220446049250313e-16.
#   warn(message.format("`ftol`", EPS))
# /galbadata/analysis/packages/anaconda3/lib/python3.6/site-packages/scipy/optimize/_lsq/least_squares.py:114: UserWarning: `xtol` is too low, setting to machine epsilon 2.220446049250313e-16.
#   warn(message.format("`xtol`", EPS))
#  Fitting frequency bin  50  out of  21875
#
#  ======  0.2 percent Done ================
#
#  Fitting frequency bin  100  out of  21875
#
#  ======  0.5 percent Done ================
#
#  Fitting frequency bin  150  out of  21875
#
#  ======  0.7000000000000001 percent Done ================
#
#  Fitting frequency bin  200  out of  21875
#
#  ======  0.8999999999999999 percent Done ================
#
#  Fitting frequency bin  250  out of  21875
#
#  ======  1.0999999999999999 percent Done ================
#
#  Fitting frequency bin  300  out of  21875
#
#  ======  1.4000000000000001 percent Done ================
#
#  Fitting frequency bin  350  out of  21875
#
#  ======  1.6 percent Done ================
#
#  Fitting frequency bin  400  out of  21875
#
#  ======  1.7999999999999998 percent Done ================
#
#  Fitting frequency bin  450  out of  21875
#
#  ======  2.1 percent Done ================
#
#  Fitting frequency bin  500  out of  21875
#
#  ======  2.3 percent Done ================
#
#  Fitting frequency bin  550  out of  21875
#
#  ======  2.5 percent Done ================
#
#  Fitting frequency bin  600  out of  21875
#
#  ======  2.7 percent Done ================
#
#  Fitting frequency bin  650  out of  21875
#
#  ======  3.0 percent Done ================
#
#  Fitting frequency bin  700  out of  21875
#
#  ======  3.2 percent Done ================
#
#  Fitting frequency bin  750  out of  21875
#
#  ======  3.4000000000000004 percent Done ================
#
#  Fitting frequency bin  800  out of  21875
#
#  ======  3.6999999999999997 percent Done ================
#
#  Fitting frequency bin  850  out of  21875
#
#  ======  3.9 percent Done ================
#
#  Fitting frequency bin  900  out of  21875
#
#  ======  4.1000000000000005 percent Done ================
#
#  Fitting frequency bin  950  out of  21875
#
#  ======  4.3 percent Done ================
#
#  Fitting frequency bin  1000  out of  21875
#
#  ======  4.6 percent Done ================
#
#  Fitting frequency bin  1050  out of  21875
#
#  ======  4.8 percent Done ================
#
#  Fitting frequency bin  1100  out of  21875
#
#  ======  5.0 percent Done ================
#
#  Fitting frequency bin  1150  out of  21875
#
#  ======  5.3 percent Done ================
#
#  Fitting frequency bin  1200  out of  21875
#
#  ======  5.5 percent Done ================
#
#  Fitting frequency bin  1250  out of  21875
#
#  ======  5.7 percent Done ================
#
#  Fitting frequency bin  1300  out of  21875
#
#  ======  5.8999999999999995 percent Done ================
#
#  Fitting frequency bin  1350  out of  21875
#
#  ======  6.2 percent Done ================
#
#  Fitting frequency bin  1400  out of  21875
#
#  ======  6.4 percent Done ================
#
#  Fitting frequency bin  1450  out of  21875
#
#  ======  6.6000000000000005 percent Done ================
#
#  Fitting frequency bin  1500  out of  21875
#
#  ======  6.9 percent Done ================
#
#  Fitting frequency bin  1550  out of  21875
#
#  ======  7.1 percent Done ================
#
#  Fitting frequency bin  1600  out of  21875
#
#  ======  7.3 percent Done ================
#
#  Fitting frequency bin  1650  out of  21875
#
#  ======  7.5 percent Done ================
#
#  Fitting frequency bin  1700  out of  21875
#
#  ======  7.8 percent Done ================
#
#  Fitting frequency bin  1750  out of  21875
#
#  ======  8.0 percent Done ================
#
#  Fitting frequency bin  1800  out of  21875
#
#  ======  8.200000000000001 percent Done ================
#
#  Fitting frequency bin  1850  out of  21875
#
#  ======  8.5 percent Done ================
#
#  Fitting frequency bin  1900  out of  21875
#
#  ======  8.7 percent Done ================
#
#  Fitting frequency bin  1950  out of  21875
#
#  ======  8.9 percent Done ================
#
#  Fitting frequency bin  2000  out of  21875
#
#  ======  9.1 percent Done ================
#
#  Fitting frequency bin  2050  out of  21875
#
#  ======  9.4 percent Done ================
#
#  Fitting frequency bin  2100  out of  21875
#
#  ======  9.6 percent Done ================
#
#  Fitting frequency bin  2150  out of  21875
#
#  ======  9.8 percent Done ================
#
#  Fitting frequency bin  2200  out of  21875
#
#  ======  10.100000000000001 percent Done ================
#
#  Fitting frequency bin  2250  out of  21875
#
#  ======  10.299999999999999 percent Done ================
#
#  Fitting frequency bin  2300  out of  21875
#
#  ======  10.5 percent Done ================
#
#  Fitting frequency bin  2350  out of  21875
#
#  ======  10.7 percent Done ================
#
#  Fitting frequency bin  2400  out of  21875
#
#  ======  11.0 percent Done ================
#
#  Fitting frequency bin  2450  out of  21875
#
#  ======  11.200000000000001 percent Done ================
#
#  Fitting frequency bin  2500  out of  21875
#
#  ======  11.4 percent Done ================
#
#  Fitting frequency bin  2550  out of  21875
#
#  ======  11.700000000000001 percent Done ================
#
#  Fitting frequency bin  2600  out of  21875
#
#  ======  11.899999999999999 percent Done ================
#
#  Fitting frequency bin  2650  out of  21875
#
#  ======  12.1 percent Done ================
#
#  Fitting frequency bin  2700  out of  21875
#
#  ======  12.3 percent Done ================
#
#  Fitting frequency bin  2750  out of  21875
#
#  ======  12.6 percent Done ================
#
#  Fitting frequency bin  2800  out of  21875
#
#  ======  12.8 percent Done ================
#
#  Fitting frequency bin  2850  out of  21875
#
#  ======  13.0 percent Done ================
#
#  Fitting frequency bin  2900  out of  21875
#
#  ======  13.3 percent Done ================
#
#  Fitting frequency bin  2950  out of  21875
#
#  ======  13.5 percent Done ================
#
#  Fitting frequency bin  3000  out of  21875
#
#  ======  13.700000000000001 percent Done ================
#
#  Fitting frequency bin  3050  out of  21875
#
#  ======  13.900000000000002 percent Done ================
#
#  Fitting frequency bin  3100  out of  21875
#
#  ======  14.2 percent Done ================
#
#  Fitting frequency bin  3150  out of  21875
#
#  ======  14.399999999999999 percent Done ================
#
#  Fitting frequency bin  3200  out of  21875
#
#  ======  14.6 percent Done ================
#
#  Fitting frequency bin  3250  out of  21875
#
#  ======  14.899999999999999 percent Done ================
#
#  Fitting frequency bin  3300  out of  21875
#
#  ======  15.1 percent Done ================
#
#  Fitting frequency bin  3350  out of  21875
#
#  ======  15.299999999999999 percent Done ================
#
#  Fitting frequency bin  3400  out of  21875
#
#  ======  15.5 percent Done ================
#
#  Fitting frequency bin  3450  out of  21875
#
#  ======  15.8 percent Done ================
#
#  Fitting frequency bin  3500  out of  21875
#
#  ======  16.0 percent Done ================
#
#  Fitting frequency bin  3550  out of  21875
#
#  ======  16.2 percent Done ================
#
#  Fitting frequency bin  3600  out of  21875
#
#  ======  16.5 percent Done ================
#
#  Fitting frequency bin  3650  out of  21875
#
#  ======  16.7 percent Done ================
#
#  Fitting frequency bin  3700  out of  21875
#
#  ======  16.900000000000002 percent Done ================
#
#  Fitting frequency bin  3750  out of  21875
#
#  ======  17.1 percent Done ================
#
#  Fitting frequency bin  3800  out of  21875
#
#  ======  17.4 percent Done ================
#
#  Fitting frequency bin  3850  out of  21875
#
#  ======  17.599999999999998 percent Done ================
#
#  Fitting frequency bin  3900  out of  21875
#
#  ======  17.8 percent Done ================
#
#  Fitting frequency bin  3950  out of  21875
#
#  ======  18.099999999999998 percent Done ================
#
#  Fitting frequency bin  4000  out of  21875
#
#  ======  18.3 percent Done ================
#
#  Fitting frequency bin  4050  out of  21875
#
#  ======  18.5 percent Done ================
#
#  Fitting frequency bin  4100  out of  21875
#
#  ======  18.7 percent Done ================
#
#  Fitting frequency bin  4150  out of  21875
#
#  ======  19.0 percent Done ================
#
#  Fitting frequency bin  4200  out of  21875
#
#  ======  19.2 percent Done ================
#
#  Fitting frequency bin  4250  out of  21875
#
#  ======  19.400000000000002 percent Done ================
#
#  Fitting frequency bin  4300  out of  21875
#
#  ======  19.7 percent Done ================
#
#  Fitting frequency bin  4350  out of  21875
#
#  ======  19.900000000000002 percent Done ================
#
#  Fitting frequency bin  4400  out of  21875
#
#  ======  20.1 percent Done ================
#
#  Fitting frequency bin  4450  out of  21875
#
#  ======  20.3 percent Done ================
#
#  Fitting frequency bin  4500  out of  21875
#
#  ======  20.599999999999998 percent Done ================
#
#  Fitting frequency bin  4550  out of  21875
#
#  ======  20.8 percent Done ================
#
#  Fitting frequency bin  4600  out of  21875
#
#  ======  21.0 percent Done ================
#
#  Fitting frequency bin  4650  out of  21875
#
#  ======  21.3 percent Done ================
#
#  Fitting frequency bin  4700  out of  21875
#
#  ======  21.5 percent Done ================
#
#  Fitting frequency bin  4750  out of  21875
#
#  ======  21.7 percent Done ================
#
#  Fitting frequency bin  4800  out of  21875
#
#  ======  21.9 percent Done ================
#
#  Fitting frequency bin  4850  out of  21875
#
#  ======  22.2 percent Done ================
#
#  Fitting frequency bin  4900  out of  21875
#
#  ======  22.400000000000002 percent Done ================
#
#  Fitting frequency bin  4950  out of  21875
#
#  ======  22.6 percent Done ================
#
#  Fitting frequency bin  5000  out of  21875
#
#  ======  22.900000000000002 percent Done ================
#
#  Fitting frequency bin  5050  out of  21875
#
#  ======  23.1 percent Done ================
#
#  Fitting frequency bin  5100  out of  21875
#
#  ======  23.3 percent Done ================
#
#  Fitting frequency bin  5150  out of  21875
#
#  ======  23.5 percent Done ================
#
#  Fitting frequency bin  5200  out of  21875
#
#  ======  23.799999999999997 percent Done ================
#
#  Fitting frequency bin  5250  out of  21875
#
#  ======  24.0 percent Done ================
#
#  Fitting frequency bin  5300  out of  21875
#
#  ======  24.2 percent Done ================
#
#  Fitting frequency bin  5350  out of  21875
#
#  ======  24.5 percent Done ================
#
#  Fitting frequency bin  5400  out of  21875
#
#  ======  24.7 percent Done ================
#
#  Fitting frequency bin  5450  out of  21875
#
#  ======  24.9 percent Done ================
#
#  Fitting frequency bin  5500  out of  21875
#
#  ======  25.1 percent Done ================
#
#  Fitting frequency bin  5550  out of  21875
#
#  ======  25.4 percent Done ================
#
#  Fitting frequency bin  5600  out of  21875
#
#  ======  25.6 percent Done ================
#
#  Fitting frequency bin  5650  out of  21875
#
#  ======  25.8 percent Done ================
#
#  Fitting frequency bin  5700  out of  21875
#
#  ======  26.1 percent Done ================
#
#  Fitting frequency bin  5750  out of  21875
#
#  ======  26.3 percent Done ================
#
#  Fitting frequency bin  5800  out of  21875
#
#  ======  26.5 percent Done ================
#
#  Fitting frequency bin  5850  out of  21875
#
#  ======  26.700000000000003 percent Done ================
#
#  Fitting frequency bin  5900  out of  21875
#
#  ======  27.0 percent Done ================
#
#  Fitting frequency bin  5950  out of  21875
#
#  ======  27.200000000000003 percent Done ================
#
#  Fitting frequency bin  6000  out of  21875
#
#  ======  27.400000000000002 percent Done ================
#
#  Fitting frequency bin  6050  out of  21875
#
#  ======  27.700000000000003 percent Done ================
#
#  Fitting frequency bin  6100  out of  21875
#
#  ======  27.900000000000002 percent Done ================
#
#  Fitting frequency bin  6150  out of  21875
#
#  ======  28.1 percent Done ================
#
#  Fitting frequency bin  6200  out of  21875
#
#  ======  28.299999999999997 percent Done ================
#
#  Fitting frequency bin  6250  out of  21875
#
#  ======  28.599999999999998 percent Done ================
#
#  Fitting frequency bin  6300  out of  21875
#
#  ======  28.799999999999997 percent Done ================
#
#  Fitting frequency bin  6350  out of  21875
#
#  ======  28.999999999999996 percent Done ================
#
#  Fitting frequency bin  6400  out of  21875
#
#  ======  29.299999999999997 percent Done ================
#
#  Fitting frequency bin  6450  out of  21875
#
#  ======  29.5 percent Done ================
#
#  Fitting frequency bin  6500  out of  21875
#
#  ======  29.7 percent Done ================
#
#  Fitting frequency bin  6550  out of  21875
#
#  ======  29.9 percent Done ================
#
#  Fitting frequency bin  6600  out of  21875
#
#  ======  30.2 percent Done ================
#
#  Fitting frequency bin  6650  out of  21875
#
#  ======  30.4 percent Done ================
#
#  Fitting frequency bin  6700  out of  21875
#
#  ======  30.599999999999998 percent Done ================
#
#  Fitting frequency bin  6750  out of  21875
#
#  ======  30.9 percent Done ================
#
#  Fitting frequency bin  6800  out of  21875
#
#  ======  31.1 percent Done ================
#
#  Fitting frequency bin  6850  out of  21875
#
#  ======  31.3 percent Done ================
#
#  Fitting frequency bin  6900  out of  21875
#
#  ======  31.5 percent Done ================
#
#  Fitting frequency bin  6950  out of  21875
#
#  ======  31.8 percent Done ================
#
#  Fitting frequency bin  7000  out of  21875
#
#  ======  32.0 percent Done ================
#
#  Fitting frequency bin  7050  out of  21875
#
#  ======  32.2 percent Done ================
#
#  Fitting frequency bin  7100  out of  21875
#
#  ======  32.5 percent Done ================
#
#  Fitting frequency bin  7150  out of  21875
#
#  ======  32.7 percent Done ================
#
#  Fitting frequency bin  7200  out of  21875
#
#  ======  32.9 percent Done ================
#
#  Fitting frequency bin  7250  out of  21875
#
#  ======  33.1 percent Done ================
#
#  Fitting frequency bin  7300  out of  21875
#
#  ======  33.4 percent Done ================
#
#  Fitting frequency bin  7350  out of  21875
#
#  ======  33.6 percent Done ================
#
#  Fitting frequency bin  7400  out of  21875
#
#  ======  33.800000000000004 percent Done ================
#
#  Fitting frequency bin  7450  out of  21875
#
#  ======  34.1 percent Done ================
#
#  Fitting frequency bin  7500  out of  21875
#
#  ======  34.300000000000004 percent Done ================
#
#  Fitting frequency bin  7550  out of  21875
#
#  ======  34.5 percent Done ================
#
#  Fitting frequency bin  7600  out of  21875
#
#  ======  34.699999999999996 percent Done ================
#
#  Fitting frequency bin  7650  out of  21875
#
#  ======  35.0 percent Done ================
#
#  Fitting frequency bin  7700  out of  21875
#
#  ======  35.199999999999996 percent Done ================
#
#  Fitting frequency bin  7750  out of  21875
#
#  ======  35.4 percent Done ================
#
#  Fitting frequency bin  7800  out of  21875
#
#  ======  35.699999999999996 percent Done ================
#
#  Fitting frequency bin  7850  out of  21875
#
#  ======  35.9 percent Done ================
#
#  Fitting frequency bin  7900  out of  21875
#
#  ======  36.1 percent Done ================
#
#  Fitting frequency bin  7950  out of  21875
#
#  ======  36.3 percent Done ================
#
#  Fitting frequency bin  8000  out of  21875
#
#  ======  36.6 percent Done ================
#
#  Fitting frequency bin  8050  out of  21875
#
#  ======  36.8 percent Done ================
#
#  Fitting frequency bin  8100  out of  21875
#
#  ======  37.0 percent Done ================
#
#  Fitting frequency bin  8150  out of  21875
#
#  ======  37.3 percent Done ================
#
#  Fitting frequency bin  8200  out of  21875
#
#  ======  37.5 percent Done ================
#
#  Fitting frequency bin  8250  out of  21875
#
#  ======  37.7 percent Done ================
#
#  Fitting frequency bin  8300  out of  21875
#
#  ======  37.9 percent Done ================
#
#  Fitting frequency bin  8350  out of  21875
#
#  ======  38.2 percent Done ================
#
#  Fitting frequency bin  8400  out of  21875
#
#  ======  38.4 percent Done ================
#
#  Fitting frequency bin  8450  out of  21875
#
#  ======  38.6 percent Done ================
#
#  Fitting frequency bin  8500  out of  21875
#
#  ======  38.9 percent Done ================
#
#  Fitting frequency bin  8550  out of  21875
#
#  ======  39.1 percent Done ================
#
#  Fitting frequency bin  8600  out of  21875
#
#  ======  39.300000000000004 percent Done ================
#
#  Fitting frequency bin  8650  out of  21875
#
#  ======  39.5 percent Done ================
#
#  Fitting frequency bin  8700  out of  21875
#
#  ======  39.800000000000004 percent Done ================
#
#  Fitting frequency bin  8750  out of  21875
#
#  ======  40.0 percent Done ================
#
#  Fitting frequency bin  8800  out of  21875
#
#  ======  40.2 percent Done ================
#
#  Fitting frequency bin  8850  out of  21875
#
#  ======  40.5 percent Done ================
#
#  Fitting frequency bin  8900  out of  21875
#
#  ======  40.699999999999996 percent Done ================
#
#  Fitting frequency bin  8950  out of  21875
#
#  ======  40.9 percent Done ================
#
#  Fitting frequency bin  9000  out of  21875
#
#  ======  41.099999999999994 percent Done ================
#
#  Fitting frequency bin  9050  out of  21875
#
#  ======  41.4 percent Done ================
#
#  Fitting frequency bin  9100  out of  21875
#
#  ======  41.6 percent Done ================
#
#  Fitting frequency bin  9150  out of  21875
#
#  ======  41.8 percent Done ================
#
#  Fitting frequency bin  9200  out of  21875
#
#  ======  42.1 percent Done ================
#
#  Fitting frequency bin  9250  out of  21875
#
#  ======  42.3 percent Done ================
#
#  Fitting frequency bin  9300  out of  21875
#
#  ======  42.5 percent Done ================
#
#  Fitting frequency bin  9350  out of  21875
#
#  ======  42.699999999999996 percent Done ================
#
#  Fitting frequency bin  9400  out of  21875
#
#  ======  43.0 percent Done ================
#
#  Fitting frequency bin  9450  out of  21875
#
#  ======  43.2 percent Done ================
#
#  Fitting frequency bin  9500  out of  21875
#
#  ======  43.4 percent Done ================
#
#  Fitting frequency bin  9550  out of  21875
#
#  ======  43.7 percent Done ================
#
#  Fitting frequency bin  9600  out of  21875
#
#  ======  43.9 percent Done ================
#
#  Fitting frequency bin  9650  out of  21875
#
#  ======  44.1 percent Done ================
#
#  Fitting frequency bin  9700  out of  21875
#
#  ======  44.3 percent Done ================
#
#  Fitting frequency bin  9750  out of  21875
#
#  ======  44.6 percent Done ================
#
#  Fitting frequency bin  9800  out of  21875
#
#  ======  44.800000000000004 percent Done ================
#
#  Fitting frequency bin  9850  out of  21875
#
#  ======  45.0 percent Done ================
#
#  Fitting frequency bin  9900  out of  21875
#
#  ======  45.300000000000004 percent Done ================
#
#  Fitting frequency bin  9950  out of  21875
#
#  ======  45.5 percent Done ================
#
#  Fitting frequency bin  10000  out of  21875
#
#  ======  45.7 percent Done ================
#
#  Fitting frequency bin  10050  out of  21875
#
#  ======  45.9 percent Done ================
#
#  Fitting frequency bin  10100  out of  21875
#
#  ======  46.2 percent Done ================
#
#  Fitting frequency bin  10150  out of  21875
#
#  ======  46.400000000000006 percent Done ================
#
#  Fitting frequency bin  10200  out of  21875
#
#  ======  46.6 percent Done ================
#
#  Fitting frequency bin  10250  out of  21875
#
#  ======  46.9 percent Done ================
#
#  Fitting frequency bin  10300  out of  21875
#
#  ======  47.099999999999994 percent Done ================
#
#  Fitting frequency bin  10350  out of  21875
#
#  ======  47.3 percent Done ================
#
#  Fitting frequency bin  10400  out of  21875
#
#  ======  47.5 percent Done ================
#
#  Fitting frequency bin  10450  out of  21875
#
#  ======  47.8 percent Done ================
#
#  Fitting frequency bin  10500  out of  21875
#
#  ======  48.0 percent Done ================
#
#  Fitting frequency bin  10550  out of  21875
#
#  ======  48.199999999999996 percent Done ================
#
#  Fitting frequency bin  10600  out of  21875
#
#  ======  48.5 percent Done ================
#
#  Fitting frequency bin  10650  out of  21875
#
#  ======  48.699999999999996 percent Done ================
#
#  Fitting frequency bin  10700  out of  21875
#
#  ======  48.9 percent Done ================
#
#  Fitting frequency bin  10750  out of  21875
#
#  ======  49.1 percent Done ================
#
#  Fitting frequency bin  10800  out of  21875
#
#  ======  49.4 percent Done ================
#
#  Fitting frequency bin  10850  out of  21875
#
#  ======  49.6 percent Done ================
#
#  Fitting frequency bin  10900  out of  21875
#
#  ======  49.8 percent Done ================
#
#  Fitting frequency bin  10950  out of  21875
#
#  ======  50.1 percent Done ================
#
#  Fitting frequency bin  11000  out of  21875
#
#  ======  50.3 percent Done ================
#
#  Fitting frequency bin  11050  out of  21875
#
#  ======  50.5 percent Done ================
#
#  Fitting frequency bin  11100  out of  21875
#
#  ======  50.7 percent Done ================
#
#  Fitting frequency bin  11150  out of  21875
#
#  ======  51.0 percent Done ================
#
#  Fitting frequency bin  11200  out of  21875
#
#  ======  51.2 percent Done ================
#
#  Fitting frequency bin  11250  out of  21875
#
#  ======  51.4 percent Done ================
#
#  Fitting frequency bin  11300  out of  21875
#
#  ======  51.7 percent Done ================
#
#  Fitting frequency bin  11350  out of  21875
#
#  ======  51.9 percent Done ================
#
#  Fitting frequency bin  11400  out of  21875
#
#  ======  52.1 percent Done ================
#
#  Fitting frequency bin  11450  out of  21875
#
#  ======  52.300000000000004 percent Done ================
#
#  Fitting frequency bin  11500  out of  21875
#
#  ======  52.6 percent Done ================
#
#  Fitting frequency bin  11550  out of  21875
#
#  ======  52.800000000000004 percent Done ================
#
#  Fitting frequency bin  11600  out of  21875
#
#  ======  53.0 percent Done ================
#
#  Fitting frequency bin  11650  out of  21875
#
#  ======  53.300000000000004 percent Done ================
#
#  Fitting frequency bin  11700  out of  21875
#
#  ======  53.5 percent Done ================
#
#  Fitting frequency bin  11750  out of  21875
#
#  ======  53.7 percent Done ================
#
#  Fitting frequency bin  11800  out of  21875
#
#  ======  53.900000000000006 percent Done ================
#
#  Fitting frequency bin  11850  out of  21875
#
#  ======  54.2 percent Done ================
#
#  Fitting frequency bin  11900  out of  21875
#
#  ======  54.400000000000006 percent Done ================
#
#  Fitting frequency bin  11950  out of  21875
#
#  ======  54.6 percent Done ================
#
#  Fitting frequency bin  12000  out of  21875
#
#  ======  54.900000000000006 percent Done ================
#
#  Fitting frequency bin  12050  out of  21875
#
#  ======  55.1 percent Done ================
#
#  Fitting frequency bin  12100  out of  21875
#
#  ======  55.300000000000004 percent Done ================
#
#  Fitting frequency bin  12150  out of  21875
#
#  ======  55.50000000000001 percent Done ================
#
#  Fitting frequency bin  12200  out of  21875
#
#  ======  55.800000000000004 percent Done ================
#
#  Fitting frequency bin  12250  out of  21875
#
#  ======  56.00000000000001 percent Done ================
#
#  Fitting frequency bin  12300  out of  21875
#
#  ======  56.2 percent Done ================
#
#  Fitting frequency bin  12350  out of  21875
#
#  ======  56.49999999999999 percent Done ================
#
#  Fitting frequency bin  12400  out of  21875
#
#  ======  56.699999999999996 percent Done ================
#
#  Fitting frequency bin  12450  out of  21875
#
#  ======  56.89999999999999 percent Done ================
#
#  Fitting frequency bin  12500  out of  21875
#
#  ======  57.099999999999994 percent Done ================
#
#  Fitting frequency bin  12550  out of  21875
#
#  ======  57.4 percent Done ================
#
#  Fitting frequency bin  12600  out of  21875
#
#  ======  57.599999999999994 percent Done ================
#
#  Fitting frequency bin  12650  out of  21875
#
#  ======  57.8 percent Done ================
#
#  Fitting frequency bin  12700  out of  21875
#
#  ======  58.099999999999994 percent Done ================
#
#  Fitting frequency bin  12750  out of  21875
#
#  ======  58.3 percent Done ================
#
#  Fitting frequency bin  12800  out of  21875
#
#  ======  58.5 percent Done ================
#
#  Fitting frequency bin  12850  out of  21875
#
#  ======  58.699999999999996 percent Done ================
#
#  Fitting frequency bin  12900  out of  21875
#
#  ======  59.0 percent Done ================
#
#  Fitting frequency bin  12950  out of  21875
#
#  ======  59.199999999999996 percent Done ================
#
#  Fitting frequency bin  13000  out of  21875
#
#  ======  59.4 percent Done ================
#
#  Fitting frequency bin  13050  out of  21875
#
#  ======  59.699999999999996 percent Done ================
#
#  Fitting frequency bin  13100  out of  21875
#
#  ======  59.9 percent Done ================
#
#  Fitting frequency bin  13150  out of  21875
#
#  ======  60.099999999999994 percent Done ================
#
#  Fitting frequency bin  13200  out of  21875
#
#  ======  60.3 percent Done ================
#
#  Fitting frequency bin  13250  out of  21875
#
#  ======  60.6 percent Done ================
#
#  Fitting frequency bin  13300  out of  21875
#
#  ======  60.8 percent Done ================
#
#  Fitting frequency bin  13350  out of  21875
#
#  ======  61.0 percent Done ================
#
#  Fitting frequency bin  13400  out of  21875
#
#  ======  61.3 percent Done ================
#
#  Fitting frequency bin  13450  out of  21875
#
#  ======  61.5 percent Done ================
#
#  Fitting frequency bin  13500  out of  21875
#
#  ======  61.7 percent Done ================
#
#  Fitting frequency bin  13550  out of  21875
#
#  ======  61.9 percent Done ================
#
#  Fitting frequency bin  13600  out of  21875
#
#  ======  62.2 percent Done ================
#
#  Fitting frequency bin  13650  out of  21875
#
#  ======  62.4 percent Done ================
#
#  Fitting frequency bin  13700  out of  21875
#
#  ======  62.6 percent Done ================
#
#  Fitting frequency bin  13750  out of  21875
#
#  ======  62.9 percent Done ================
#
#  Fitting frequency bin  13800  out of  21875
#
#  ======  63.1 percent Done ================
#
#  Fitting frequency bin  13850  out of  21875
#
#  ======  63.3 percent Done ================
#
#  Fitting frequency bin  13900  out of  21875
#
#  ======  63.5 percent Done ================
#
#  Fitting frequency bin  13950  out of  21875
#
#  ======  63.800000000000004 percent Done ================
#
#  Fitting frequency bin  14000  out of  21875
#
#  ======  64.0 percent Done ================
#
#  Fitting frequency bin  14050  out of  21875
#
#  ======  64.2 percent Done ================
#
#  Fitting frequency bin  14100  out of  21875
#
#  ======  64.5 percent Done ================
#
#  Fitting frequency bin  14150  out of  21875
#
#  ======  64.7 percent Done ================
#
#  Fitting frequency bin  14200  out of  21875
#
#  ======  64.9 percent Done ================
#
#  Fitting frequency bin  14250  out of  21875
#
#  ======  65.10000000000001 percent Done ================
#
#  Fitting frequency bin  14300  out of  21875
#
#  ======  65.4 percent Done ================
#
#  Fitting frequency bin  14350  out of  21875
#
#  ======  65.60000000000001 percent Done ================
#
#  Fitting frequency bin  14400  out of  21875
#
#  ======  65.8 percent Done ================
#
#  Fitting frequency bin  14450  out of  21875
#
#  ======  66.10000000000001 percent Done ================
#
#  Fitting frequency bin  14500  out of  21875
#
#  ======  66.3 percent Done ================
#
#  Fitting frequency bin  14550  out of  21875
#
#  ======  66.5 percent Done ================
#
#  Fitting frequency bin  14600  out of  21875
#
#  ======  66.7 percent Done ================
#
#  Fitting frequency bin  14650  out of  21875
#
#  ======  67.0 percent Done ================
#
#  Fitting frequency bin  14700  out of  21875
#
#  ======  67.2 percent Done ================
#
#  Fitting frequency bin  14750  out of  21875
#
#  ======  67.4 percent Done ================
#
#  Fitting frequency bin  14800  out of  21875
#
#  ======  67.7 percent Done ================
#
#  Fitting frequency bin  14850  out of  21875
#
#  ======  67.9 percent Done ================
#
#  Fitting frequency bin  14900  out of  21875
#
#  ======  68.10000000000001 percent Done ================
#
#  Fitting frequency bin  14950  out of  21875
#
#  ======  68.30000000000001 percent Done ================
#
#  Fitting frequency bin  15000  out of  21875
#
#  ======  68.60000000000001 percent Done ================
#
#  Fitting frequency bin  15050  out of  21875
#
#  ======  68.8 percent Done ================
#
#  Fitting frequency bin  15100  out of  21875
#
#  ======  69.0 percent Done ================
#
#  Fitting frequency bin  15150  out of  21875
#
#  ======  69.3 percent Done ================
#
#  Fitting frequency bin  15200  out of  21875
#
#  ======  69.5 percent Done ================
#
#  Fitting frequency bin  15250  out of  21875
#
#  ======  69.69999999999999 percent Done ================
#
#  Fitting frequency bin  15300  out of  21875
#
#  ======  69.89999999999999 percent Done ================
#
#  Fitting frequency bin  15350  out of  21875
#
#  ======  70.19999999999999 percent Done ================
#
#  Fitting frequency bin  15400  out of  21875
#
#  ======  70.39999999999999 percent Done ================
#
#  Fitting frequency bin  15450  out of  21875
#
#  ======  70.6 percent Done ================
#
#  Fitting frequency bin  15500  out of  21875
#
#  ======  70.89999999999999 percent Done ================
#
#  Fitting frequency bin  15550  out of  21875
#
#  ======  71.1 percent Done ================
#
#  Fitting frequency bin  15600  out of  21875
#
#  ======  71.3 percent Done ================
#
#  Fitting frequency bin  15650  out of  21875
#
#  ======  71.5 percent Done ================
#
#  Fitting frequency bin  15700  out of  21875
#
#  ======  71.8 percent Done ================
#
#  Fitting frequency bin  15750  out of  21875
#
#  ======  72.0 percent Done ================
#
#  Fitting frequency bin  15800  out of  21875
#
#  ======  72.2 percent Done ================
#
#  Fitting frequency bin  15850  out of  21875
#
#  ======  72.5 percent Done ================
#
#  Fitting frequency bin  15900  out of  21875
#
#  ======  72.7 percent Done ================
#
#  Fitting frequency bin  15950  out of  21875
#
#  ======  72.89999999999999 percent Done ================
#
#  Fitting frequency bin  16000  out of  21875
#
#  ======  73.1 percent Done ================
#
#  Fitting frequency bin  16050  out of  21875
#
#  ======  73.4 percent Done ================
#
#  Fitting frequency bin  16100  out of  21875
#
#  ======  73.6 percent Done ================
#
#  Fitting frequency bin  16150  out of  21875
#
#  ======  73.8 percent Done ================
#
#  Fitting frequency bin  16200  out of  21875
#
#  ======  74.1 percent Done ================
#
#  Fitting frequency bin  16250  out of  21875
#
#  ======  74.3 percent Done ================
#
#  Fitting frequency bin  16300  out of  21875
#
#  ======  74.5 percent Done ================
#
#  Fitting frequency bin  16350  out of  21875
#
#  ======  74.7 percent Done ================
#
#  Fitting frequency bin  16400  out of  21875
#
#  ======  75.0 percent Done ================
#
#  Fitting frequency bin  16450  out of  21875
#
#  ======  75.2 percent Done ================
#
#  Fitting frequency bin  16500  out of  21875
#
#  ======  75.4 percent Done ================
#
#  Fitting frequency bin  16550  out of  21875
#
#  ======  75.7 percent Done ================
#
#  Fitting frequency bin  16600  out of  21875
#
#  ======  75.9 percent Done ================
#
#  Fitting frequency bin  16650  out of  21875
#
#  ======  76.1 percent Done ================
#
#  Fitting frequency bin  16700  out of  21875
#
#  ======  76.3 percent Done ================
#
#  Fitting frequency bin  16750  out of  21875
#
#  ======  76.6 percent Done ================
#
#  Fitting frequency bin  16800  out of  21875
#
#  ======  76.8 percent Done ================
#
#  Fitting frequency bin  16850  out of  21875
#
#  ======  77.0 percent Done ================
#
#  Fitting frequency bin  16900  out of  21875
#
#  ======  77.3 percent Done ================
#
#  Fitting frequency bin  16950  out of  21875
#
#  ======  77.5 percent Done ================
#
#  Fitting frequency bin  17000  out of  21875
#
#  ======  77.7 percent Done ================
#
#  Fitting frequency bin  17050  out of  21875
#
#  ======  77.9 percent Done ================
#
#  Fitting frequency bin  17100  out of  21875
#
#  ======  78.2 percent Done ================
#
#  Fitting frequency bin  17150  out of  21875
#
#  ======  78.4 percent Done ================
#
#  Fitting frequency bin  17200  out of  21875
#
#  ======  78.60000000000001 percent Done ================
#
#  Fitting frequency bin  17250  out of  21875
#
#  ======  78.9 percent Done ================
#
#  Fitting frequency bin  17300  out of  21875
#
#  ======  79.10000000000001 percent Done ================
#
#  Fitting frequency bin  17350  out of  21875
#
#  ======  79.3 percent Done ================
#
#  Fitting frequency bin  17400  out of  21875
#
#  ======  79.5 percent Done ================
#
#  Fitting frequency bin  17450  out of  21875
#
#  ======  79.80000000000001 percent Done ================
#
#  Fitting frequency bin  17500  out of  21875
#
#  ======  80.0 percent Done ================
#
#  Fitting frequency bin  17550  out of  21875
#
#  ======  80.2 percent Done ================
#
#  Fitting frequency bin  17600  out of  21875
#
#  ======  80.5 percent Done ================
#
#  Fitting frequency bin  17650  out of  21875
#
#  ======  80.7 percent Done ================
#
#  Fitting frequency bin  17700  out of  21875
#
#  ======  80.9 percent Done ================
#
#  Fitting frequency bin  17750  out of  21875
#
#  ======  81.10000000000001 percent Done ================
#
#  Fitting frequency bin  17800  out of  21875
#
#  ======  81.39999999999999 percent Done ================
#
#  Fitting frequency bin  17850  out of  21875
#
#  ======  81.6 percent Done ================
#
#  Fitting frequency bin  17900  out of  21875
#
#  ======  81.8 percent Done ================
#
#  Fitting frequency bin  17950  out of  21875
#
#  ======  82.1 percent Done ================
#
#  Fitting frequency bin  18000  out of  21875
#
#  ======  82.3 percent Done ================
#
#  Fitting frequency bin  18050  out of  21875
#
#  ======  82.5 percent Done ================
#
#  Fitting frequency bin  18100  out of  21875
#
#  ======  82.69999999999999 percent Done ================
#
#  Fitting frequency bin  18150  out of  21875
#
#  ======  83.0 percent Done ================
#
#  Fitting frequency bin  18200  out of  21875
#
#  ======  83.2 percent Done ================
#
#  Fitting frequency bin  18250  out of  21875
#
#  ======  83.39999999999999 percent Done ================
#
#  Fitting frequency bin  18300  out of  21875
#
#  ======  83.7 percent Done ================
#
#  Fitting frequency bin  18350  out of  21875
#
#  ======  83.89999999999999 percent Done ================
#
#  Fitting frequency bin  18400  out of  21875
#
#  ======  84.1 percent Done ================
#
#  Fitting frequency bin  18450  out of  21875
#
#  ======  84.3 percent Done ================
#
#  Fitting frequency bin  18500  out of  21875
#
#  ======  84.6 percent Done ================
#
#  Fitting frequency bin  18550  out of  21875
#
#  ======  84.8 percent Done ================
#
#  Fitting frequency bin  18600  out of  21875
#
#  ======  85.0 percent Done ================
#
#  Fitting frequency bin  18650  out of  21875
#
#  ======  85.3 percent Done ================
#
#  Fitting frequency bin  18700  out of  21875
#
#  ======  85.5 percent Done ================
#
#  Fitting frequency bin  18750  out of  21875
#
#  ======  85.7 percent Done ================
#
#  Fitting frequency bin  18800  out of  21875
#
#  ======  85.9 percent Done ================
#
#  Fitting frequency bin  18850  out of  21875
#
#  ======  86.2 percent Done ================
#
#  Fitting frequency bin  18900  out of  21875
#
#  ======  86.4 percent Done ================
#
#  Fitting frequency bin  18950  out of  21875
#
#  ======  86.6 percent Done ================
#
#  Fitting frequency bin  19000  out of  21875
#
#  ======  86.9 percent Done ================
#
#  Fitting frequency bin  19050  out of  21875
#
#  ======  87.1 percent Done ================
#
#  Fitting frequency bin  19100  out of  21875
#
#  ======  87.3 percent Done ================
#
#  Fitting frequency bin  19150  out of  21875
#
#  ======  87.5 percent Done ================
#
#  Fitting frequency bin  19200  out of  21875
#
#  ======  87.8 percent Done ================
#
#  Fitting frequency bin  19250  out of  21875
#
#  ======  88.0 percent Done ================
#
#  Fitting frequency bin  19300  out of  21875
#
#  ======  88.2 percent Done ================
#
#  Fitting frequency bin  19350  out of  21875
#
#  ======  88.5 percent Done ================
#
#  Fitting frequency bin  19400  out of  21875
#
#  ======  88.7 percent Done ================
#
#  Fitting frequency bin  19450  out of  21875
#
#  ======  88.9 percent Done ================
#
#  Fitting frequency bin  19500  out of  21875
#
#  ======  89.1 percent Done ================
#
#  Fitting frequency bin  19550  out of  21875
#
#  ======  89.4 percent Done ================
#
#  Fitting frequency bin  19600  out of  21875
#
#  ======  89.60000000000001 percent Done ================
#
#  Fitting frequency bin  19650  out of  21875
#
#  ======  89.8 percent Done ================
#
#  Fitting frequency bin  19700  out of  21875
#
#  ======  90.10000000000001 percent Done ================
#
#  Fitting frequency bin  19750  out of  21875
#
#  ======  90.3 percent Done ================
#
#  Fitting frequency bin  19800  out of  21875
#
#  ======  90.5 percent Done ================
#
#  Fitting frequency bin  19850  out of  21875
#
#  ======  90.7 percent Done ================
#
#  Fitting frequency bin  19900  out of  21875
#
#  ======  91.0 percent Done ================
#
#  Fitting frequency bin  19950  out of  21875
#
#  ======  91.2 percent Done ================
#
#  Fitting frequency bin  20000  out of  21875
#
#  ======  91.4 percent Done ================
#
#  Fitting frequency bin  20050  out of  21875
#
#  ======  91.7 percent Done ================
#
#  Fitting frequency bin  20100  out of  21875
#
#  ======  91.9 percent Done ================
#
#  Fitting frequency bin  20150  out of  21875
#
#  ======  92.10000000000001 percent Done ================
#
#  Fitting frequency bin  20200  out of  21875
#
#  ======  92.30000000000001 percent Done ================
#
#  Fitting frequency bin  20250  out of  21875
#
#  ======  92.60000000000001 percent Done ================
#
#  Fitting frequency bin  20300  out of  21875
#
#  ======  92.80000000000001 percent Done ================
#
#  Fitting frequency bin  20350  out of  21875
#
#  ======  93.0 percent Done ================
#
#  Fitting frequency bin  20400  out of  21875
#
#  ======  93.30000000000001 percent Done ================
#
#  Fitting frequency bin  20450  out of  21875
#
#  ======  93.5 percent Done ================
#
#  Fitting frequency bin  20500  out of  21875
#
#  ======  93.7 percent Done ================
#
#  Fitting frequency bin  20550  out of  21875
#
#  ======  93.89999999999999 percent Done ================
#
#  Fitting frequency bin  20600  out of  21875
#
#  ======  94.19999999999999 percent Done ================
#
#  Fitting frequency bin  20650  out of  21875
#
#  ======  94.39999999999999 percent Done ================
#
#  Fitting frequency bin  20700  out of  21875
#
#  ======  94.6 percent Done ================
#
#  Fitting frequency bin  20750  out of  21875
#
#  ======  94.89999999999999 percent Done ================
#
#  Fitting frequency bin  20800  out of  21875
#
#  ======  95.1 percent Done ================
#
#  Fitting frequency bin  20850  out of  21875
#
#  ======  95.3 percent Done ================
#
#  Fitting frequency bin  20900  out of  21875
#
#  ======  95.5 percent Done ================
#
#  Fitting frequency bin  20950  out of  21875
#
#  ======  95.8 percent Done ================
#
#  Fitting frequency bin  21000  out of  21875
#
#  ======  96.0 percent Done ================
#
#  Fitting frequency bin  21050  out of  21875
#
#  ======  96.2 percent Done ================
#
#  Fitting frequency bin  21100  out of  21875
#
#  ======  96.5 percent Done ================
#
#  Fitting frequency bin  21150  out of  21875
#
#  ======  96.7 percent Done ================
#
#  Fitting frequency bin  21200  out of  21875
#
#  ======  96.89999999999999 percent Done ================
#
#  Fitting frequency bin  21250  out of  21875
#
#  ======  97.1 percent Done ================
#
#  Fitting frequency bin  21300  out of  21875
#
#  ======  97.39999999999999 percent Done ================
#
#  Fitting frequency bin  21350  out of  21875
#
#  ======  97.6 percent Done ================
#
#  Fitting frequency bin  21400  out of  21875
#
#  ======  97.8 percent Done ================
#
#  Fitting frequency bin  21450  out of  21875
#
#  ======  98.1 percent Done ================
#
#  Fitting frequency bin  21500  out of  21875
#
#  ======  98.3 percent Done ================
#
#  Fitting frequency bin  21550  out of  21875
#
#  ======  98.5 percent Done ================
#
#  Fitting frequency bin  21600  out of  21875
#
#  ======  98.7 percent Done ================
#
#  Fitting frequency bin  21650  out of  21875
#
#  ======  99.0 percent Done ================
#
#  Fitting frequency bin  21700  out of  21875
#
#  ======  99.2 percent Done ================
#
#  Fitting frequency bin  21750  out of  21875
#
#  ======  99.4 percent Done ================
#
#  Fitting frequency bin  21800  out of  21875
#
#  ======  99.7 percent Done ================
#
#  Fitting frequency bin  21850  out of  21875
#
#  ======  99.9 percent Done ================

# %%
g124_noise.plot_deCorrelatedNoise(lgcCorrelated=True,lgcSum = True, lgcSave=True, savePath=savePath )

# %%
g124_noise.plot_deCorrelatedNoise(lgc_overlay = True, lgcSave=True, savePath=savePath)
